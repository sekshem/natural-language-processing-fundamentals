# %%
pip install textblob

# %%
from textblob import TextBlob

text = "I absolutely loved this movie. It was fantastic!"

analysis = TextBlob(text)

print("Polarity:", analysis.sentiment.polarity)
print("Subjectivity:", analysis.sentiment.subjectivity)
# Out:
# Polarity: 0.6
# Subjectivity: 0.8500000000000001

# %%
from textblob import TextBlob

text = "I absolutely loved this movie!"

polarity = TextBlob(text).sentiment.polarity

if polarity > 0:
    print("Positive")
elif polarity < 0:
    print("Negative")
else:
    print("Neutral")
# Out:
# Positive

# %%
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 25.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %%
text = """
Sundar Pichai is the CEO of Google.
He studied at IIT Kharagpur and currently works in the United States.
"""

doc = nlp(text)

for ent in doc.ents:
    print(ent.text, "->", ent.label_)
# Out:
# Sundar Pichai -> PERSON
# Google -> ORG
# IIT Kharagpur -> FAC
# the United States -> GPE

# %%
from spacy import displacy

displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sundar Pichai
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is the CEO of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br>He studied at
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IIT Kharagpur
# ...

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "The intelligent student quickly solved the difficult problem."

doc = nlp(text)

for token in doc:
    print(
        token.text,
        "->",
        token.pos_,
        "->",
        token.tag_
    )
# Out:
# The -> DET -> DT
# intelligent -> ADJ -> JJ
# student -> NOUN -> NN
# quickly -> ADV -> RB
# solved -> VERB -> VBD
# the -> DET -> DT
# difficult -> ADJ -> JJ
# problem -> NOUN -> NN
# . -> PUNCT -> .

# %%
import spacy

print(spacy.explain("NOUN"))
print(spacy.explain("VBD"))
# Out:
# noun
# verb, past tense

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

documents = [
    "football team won the match",
    "player scored a goal in football",
    "stock market investment increased",
    "company shares rose in the market",
    "machine learning uses data",
    "artificial intelligence and machine learning"
]

vectorizer = CountVectorizer(stop_words="english")

X = vectorizer.fit_transform(documents)

lda = LatentDirichletAllocation(
    n_components=3,
    random_state=42
)

lda.fit(X)

words = vectorizer.get_feature_names_out()

for topic_index, topic in enumerate(lda.components_):
    top_words = [
        words[i]
        for i in topic.argsort()[-5:][::-1]
    ]

    print(f"Topic {topic_index + 1}:")
    print(top_words)
# Out:
# Topic 1:
# ['football', 'player', 'scored', 'goal', 'learning']
# Topic 2:
# ['stock', 'increased', 'investment', 'won', 'match']
# Topic 3:
# ['learning', 'machine', 'market', 'shares', 'rose']

# %%
# !pip install -q transformers==4.57.1 sentencepiece

# %%
import torch
import torchvision
import transformers

print("Torch:", torch.__version__)
print("Torchvision:", torchvision.__version__)
print("Transformers:", transformers.__version__)
# Out:
# Torch: 2.13.0+cu130
# Torchvision: 0.28.0+cu130
# Transformers: 4.57.1

# %%
import sys
# !{sys.executable} -m pip uninstall -y torchvision
# Out:
# Found existing installation: torchvision 0.28.0
# Uninstalling torchvision-0.28.0:
#   Successfully uninstalled torchvision-0.28.0

# %%
import sys
# !{sys.executable} -m pip install torchvision
# Out:
# ...
#   Using cached torchvision-0.28.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# ...
# Using cached torchvision-0.28.0-cp312-cp312-manylinux_2_28_x86_64.whl (7.7 MB)
# ...

# %% [markdown]
# ### Restart Runtime
#
# Please restart the Colab runtime (Runtime > Restart runtime...) for the changes to take effect. After restarting, you can re-run the `AO9ty8oNIYDu` cell and subsequent cells.

# %%
from transformers import pipeline

summarizer = pipeline(
    "summarization",
    model="facebook/bart-large-cnn"
)

text = """
Artificial intelligence is transforming many industries around the world.
Machine learning allows computer systems to learn patterns from data without
being explicitly programmed for every task. Natural language processing is
a branch of artificial intelligence that focuses on enabling computers to
understand and process human language. NLP is widely used in applications
such as chatbots, translation systems, sentiment analysis, search engines,
and text summarization.
"""

summary = summarizer(
    text,
    max_length=60,
    min_length=20,
    do_sample=False
)

print(summary[0]["summary_text"])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# Machine learning allows computer systems to learn patterns from data. NLP is widely used in applications such as chatbots, translation systems, sentiment analysis and search engines.
