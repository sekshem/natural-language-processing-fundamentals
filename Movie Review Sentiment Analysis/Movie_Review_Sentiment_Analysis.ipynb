# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    accuracy_score,
    classification_report
)

# %%
data = {
    "review": [
        "This movie was absolutely amazing",
        "I loved the acting and the story",
        "Fantastic movie with great performances",
        "One of the best movies I have watched",
        "The film was entertaining and enjoyable",
        "I hated this movie",
        "The story was boring and terrible",
        "Worst movie I have ever watched",
        "The acting was extremely bad",
        "This film was a complete waste of time"
    ],

    "sentiment": [
        "positive",
        "positive",
        "positive",
        "positive",
        "positive",
        "negative",
        "negative",
        "negative",
        "negative",
        "negative"
    ]
}

df = pd.DataFrame(data)

df
# Out:
#                                     review sentiment
# 0        This movie was absolutely amazing  positive
# 1         I loved the acting and the story  positive
# 2  Fantastic movie with great performances  positive
# 3    One of the best movies I have watched  positive
# 4  The film was entertaining and enjoyable  positive
# 5                       I hated this movie  negative
# 6        The story was boring and terrible  negative
# 7          Worst movie I have ever watched  negative
# 8             The acting was extremely bad  negative
# 9   This film was a complete waste of time  negative

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df["review"],
    df["sentiment"],
    test_size=0.2,
    random_state=42
)

# %%
vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
X_train_tfidf = vectorizer.fit_transform(X_train)

# %%
model = LogisticRegression()

model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression()

# %%
predictions = model.predict(X_test_tfidf)

print("Accuracy:", accuracy_score(y_test, predictions))

print(
    classification_report(
        y_test,
        predictions,
        zero_division=0
    )
)
# Out:
# Accuracy: 0.5
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00         1
#     positive       0.50      1.00      0.67         1
#
#     accuracy                           0.50         2
#    macro avg       0.25      0.50      0.33         2
# weighted avg       0.25      0.50      0.33         2

# %%
review = ["The movie was fantastic and I really enjoyed it"]

review_vector = vectorizer.transform(review)

prediction = model.predict(review_vector)

print("Sentiment:", prediction[0])
# Out:
# Sentiment: positive
