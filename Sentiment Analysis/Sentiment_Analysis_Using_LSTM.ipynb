# %%
import tensorflow as tf

from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %%
# Number of most frequent words to keep
vocab_size = 10000

# Maximum length of each movie review
max_length = 200

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(
    num_words=vocab_size
)

print("Number of training samples:", len(x_train))
print("Number of testing samples:", len(x_test))

print("\nFirst review (integer tokens):")
print(x_train[0])

print("\nLabel:")
print(y_train[0])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Number of training samples: 25000
# Number of testing samples: 25000
#
# First review (integer tokens):
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
#
# Label:
# 1

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(
    num_words=vocab_size
)

print("Number of training samples:", len(x_train))
print("Number of testing samples:", len(x_test))

print("\nFirst review (integer tokens):")
print(x_train[0])

print("\nLabel:")
print(y_train[0])
# Out:
# Number of training samples: 25000
# Number of testing samples: 25000
#
# First review (integer tokens):
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
#
# Label:
# 1

# %%
x_train = pad_sequences(
    x_train,
    maxlen=max_length
)

x_test = pad_sequences(
    x_test,
    maxlen=max_length
)

print("Training data shape:", x_train.shape)
print("Testing data shape:", x_test.shape)
# Out:
# Training data shape: (25000, 200)
# Testing data shape: (25000, 200)

# %%
model_lstm = Sequential([

    Embedding(
        input_dim=vocab_size,
        output_dim=128
    ),

    LSTM(
        64
    ),

    Dense(
        1,
        activation="sigmoid"
    )
])

# %%
model_lstm.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
model_lstm.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history_lstm = model_lstm.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 83s 254ms/step - accuracy: 0.7951 - loss: 0.4386 - val_accuracy: 0.8570 - val_loss: 0.3457
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 81s 257ms/step - accuracy: 0.9017 - loss: 0.2515 - val_accuracy: 0.8664 - val_loss: 0.3220
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 251ms/step - accuracy: 0.9295 - loss: 0.1859 - val_accuracy: 0.8674 - val_loss: 0.3293
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 254ms/step - accuracy: 0.9548 - loss: 0.1260 - val_accuracy: 0.8482 - val_loss: 0.3777
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 256ms/step - accuracy: 0.9679 - loss: 0.0914 - val_accuracy: 0.8648 - val_loss: 0.4748

# %%
loss, accuracy = model_lstm.evaluate(
    x_test,
    y_test
)

print("LSTM Test Loss:", loss)
print("LSTM Test Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8508 - loss: 0.5072
# LSTM Test Loss: 0.507234513759613
# LSTM Test Accuracy: 0.8508399724960327

# %%
predictions = model_lstm.predict(x_test[:5])

for i, prediction in enumerate(predictions):
    probability = prediction[0]

    if probability >= 0.5:
        sentiment = "Positive"
    else:
        sentiment = "Negative"

    print(
        f"Review {i + 1}: "
        f"{sentiment} "
        f"(Probability: {probability:.4f})"
    )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Review 1: Negative (Probability: 0.1443)
# Review 2: Positive (Probability: 0.9992)
# Review 3: Negative (Probability: 0.0714)
# Review 4: Positive (Probability: 0.8494)
# Review 5: Positive (Probability: 0.9999)
